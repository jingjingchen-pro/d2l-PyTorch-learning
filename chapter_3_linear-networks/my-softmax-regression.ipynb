# %%
import numpy as np
from d2l import torch as d2l

# %%
x = np.arange(0, 1, 0.01)

d2l.plot(x, [-x * np.log(x), -np.log(x)], ylim=(0, 1))
# Out:
# C:\Users\jingj\AppData\Local\Temp\ipykernel_47148\2548047916.py:3: RuntimeWarning: divide by zero encountered in log
#   d2l.plot(x, [-x * np.log(x), -np.log(x)], ylim=(0, 1))
# C:\Users\jingj\AppData\Local\Temp\ipykernel_47148\2548047916.py:3: RuntimeWarning: invalid value encountered in multiply
#   d2l.plot(x, [-x * np.log(x), -np.log(x)], ylim=(0, 1))
